# %%
import numpy as np

# %%
import pandas as pd
import sklearn import datasets
# Out:
#   Cell In[2], line 2
#     import sklearn import datasets
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
from sklearn import datasets

# %%
data_wine = datasets.loadl_wine()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\sklearn\datasets\__init__.py:163, in __getattr__(name)
#     162 try:
# --> 163     return globals()[name]
#     164 except KeyError:
#     165     # This is turned into the appropriate ImportError
#
# KeyError: 'loadl_wine'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_wine = datasets.loadl_wine()
#
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\sklearn\datasets\__init__.py:166, in __getattr__(name)
#     163     return globals()[name]
#     164 except KeyError:
#     165     # This is turned into the appropriate ImportError
# --> 166     raise AttributeError
#
# AttributeError:

# %%
data_wine = datasets.load_wine()

# %%
df = pd.DataFrame(data=data_wine.data, columns=data_wine.feature_names)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df["target"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df["target"].value_counts()
#
# ...

# %%
df["target"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'target'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df["target"].value_counts()
#
# ...

# %%
pd.DataFrame(wine.target, columns=["target"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.DataFrame(wine.target, columns=["target"])
#
# NameError: name 'wine' is not defined

# %%
df["target"] = data_wine.target

# %%
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df["target"].value_counts()
# Out:
# target
# 1    71
# 0    59
# 2    48
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(5, 3, figsize=(20,15))
ax_f = ax.flatten()

for i, col_i in enumerate(df.columns):
    sns.boxplot(data=df, x="target", y=col_i, ax=ax_f[i])

# %%
from sklearn.model_selection import train_test_split
train, val = train_test_split(df, test_size=0.1)
print(df.shape)
print(train.shape)
print(val.shape)
# Out:
# (178, 14)
# (160, 14)
# (18, 14)

# %%
feat = df.drop("target", axis=1).columns
feat
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

model = LogisticRegression()
#model = RandomForestClassifier()

model.fit(train[feat], train["target"])
pred = model.predict(val[feat])
# Out:
# C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
pred
# Out:
# array([1, 0, 0, 0, 0, 2, 1, 2, 2, 1, 0, 2, 0, 2, 1, 0, 2, 0])

# %%
pred
# Out:
# array([1, 0, 0, 0, 0, 2, 1, 2, 2, 1, 0, 2, 0, 2, 1, 0, 2, 0])

# %%
from sklearn.metrics import f1_score, confusion_matrix
f1 = f1_score(pred, val["target"], average="macro")

f1
# Out:
# 1.0

# %%
sns.heatmap(confusion_matrix(pred, val["target"]), annot=True)
plt.xlabel("pred")
plt.ylabel("true")
# Out:
# Text(50.722222222222214, 0.5, 'true')

# %%
f1
# Out:
# 1.0

# %%
df = pd.read_csv('data/test.csv')

# %%
df.head()
# Out:
#      product_id  line  batch_count  tray_no  position
# 0  P10001000203     1        10002        3         3
# 1  P10001000210     1        10002        3        10
# 2  P10001000314     1        10003       26        14
# 3  P10001000407     1        10004        7         7
# 4  P10001000410     1        10004        7        10

# %%
TEST_CSV = "data/test.csv"
MACHINE_LOG_CSV = "data/machine_log.csv"
SUB_CSV = "data/sample_submission.csv"

train = pd.read_csv(TEST_CSV)
test = pd.read_csv(TEST_CSV)
log = pd.read_csv(MACHINE_LOG_CSV)
sub = pd.read_csv(SUB_CSV)

# %%
print(train.shape)
display(train.head())

print(test.shape)
display(test.head())

print(log.shape)
display(log.head())

print(sub.shape)
display(sub.head())
# Out:
# (100000, 5)
#      product_id  line  batch_count  tray_no  position
# 0  P10001000203     1        10002        3         3
# 1  P10001000210     1        10002        3        10
# 2  P10001000314     1        10003       26        14
# 3  P10001000407     1        10004        7         7
# 4  P10001000410     1        10004        7        10
# (100000, 5)
#      product_id  line  batch_count  tray_no  position
# 0  P10001000203     1        10002        3         3
# 1  P10001000210     1        10002        3        10
# 2  P10001000314     1        10003       26        14
# 3  P10001000407     1        10004        7         7
# 4  P10001000410     1        10004        7        10
# (2400000, 9)
#               datetime  line  maintenance_count  batch_count  process_time  \
# 0  2022-02-01 00:00:12     1                  0            1             1
# 1  2022-02-01 00:00:13     1                  0            1             2
# ...

# %%
import seaborn as sns

plt.figure(figsize=[20,5])
sns.countplot(data=train, x="tray_no", hue="rank")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 4
#       1 import seaborn as sns
#       3 plt.figure(figsize=[20,5])
# ----> 4 sns.countplot(data=train, x="tray_no", hue="rank")
#
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
# ...

# %%
TEST_CSV = "data/test.csv"
TRAIN_CSV = "data/train.csv"
MACHINE_LOG_CSV = "data/machine_log.csv"
SUB_CSV = "data/sample_submission.csv"

plt.figure(figsize=[20,5])
sns.countplot(data=train, x="tray_no", hue="rank")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 7
#       4 SUB_CSV = "data/sample_submission.csv"
#       6 plt.figure(figsize=[20,5])
# ----> 7 sns.countplot(data=train, x="tray_no", hue="rank")
#
# File C:\GitHub_Repos\AI_Conpe_202502\venv202502\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
# ...

# %%
train = pd.read_csv(TRAIN_CSV)
test = pd.read_csv(TEST_CSV)
log = pd.read_csv(MACHINE_LOG_CSV)
sub = pd.read_csv(SUB_CSV)

plt.figure(figsize=[20, 5])
sns.countplot(data=train, x="tray_no", hue="rank")
# Out:
# <Axes: xlabel='tray_no', ylabel='count'>

# %%
import random
A_idx = random.sample(list(train.query("rank == 'A'").index), 10)
B_idx = random.sample(list(train.query("rank == 'B'").index), 10)
C_idx = random.sample(list(train.query("rank == 'C'").index), 10)
D_idx = random.sample(list(train.query("rank == 'D'").index), 10)

fig, ax = plt.subplots(2,2, figsize=[15,10])
plt.suptitle("time series of sensor, red: A, blue : D")
ax = ax.flatten()

for idx in A_idx:
    line = train.loc[idx, "line"]
    batch = train.loc[idx, "batch_count"]
    tray_no = train.loc[idx, "tray_no"]
    position = train.loc[idx, "position"]
    _log = log.query("line == @line and batch_count == @batch")
    ax[0].plot(_log["process_time"], _log["temperature_1"], color="red")
    ax[1].plot(_log["process_time"], _log["temperature_2"], color="red")
    ax[2].plot(_log["process_time"], _log["temperature_3"], color="red")
    ax[3].plot(_log["process_time"], _log["pressure"], color="red")



    
for idx in D_idx:
    line = train.loc[idx, "line"]
    batch = train.loc[idx, "batch_count"]
    tray_no = train.loc[idx, "tray_no"]
    position = train.loc[idx, "position"]
    _log = log.query("line == @line and batch_count == @batch")
    ax[0].plot(_log["process_time"], _log["temperature_1"], color="blue")
    ax[1].plot(_log["process_time"], _log["temperature_2"], color="blue")
    ax[2].plot(_log["process_time"], _log["temperature_3"], color="blue")
    ax[3].plot(_log["process_time"], _log["pressure"], color="blue")

    
ax[0].set_title("temprature_1")
ax[1].set_title("temprature_2")
ax[2].set_title("temprature_3")
ax[3].set_title("pressure")
# Out:
# Text(0.5, 1.0, 'pressure')
